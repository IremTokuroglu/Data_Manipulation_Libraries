# %% [markdown]
# # <font color='green'> <b>Importing Libraries </b><font color='black'>

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # <font color='green'> <b>DataFrames </b><font color='black'>

# %% [markdown]
# ## <font color='blue'> <b>Conditional Selection</b><font color='black'>

# %%
np.random.seed(45)

data = np.random.randint(1,100, 20).reshape(5, 4)

df = pd.DataFrame(data, index= range(101,106), columns=["col1","col2","col3","col4"])

df
# Out:
#      col1  col2  col3  col4
# 101    76    31     4    33
# 102    96    62    86    36
# 103    69    16    66    15
# 104    54    58    73    88
# 105    47     9    54    13

# %%
df.index = "a b c d e".split()

# %%
df
# Out:
#    col1  col2  col3  col4
# a    76    31     4    33
# b    96    62    86    36
# c    69    16    66    15
# d    54    58    73    88
# e    47     9    54    13

# %%
df > 50
# Out:
#     col1   col2   col3   col4
# a   True  False  False  False
# b   True   True   True  False
# c   True  False   True  False
# d   True   True   True   True
# e  False  False   True  False

# %%
df[df > 50]
# Out:
#    col1  col2  col3  col4
# a  76.0   NaN   NaN   NaN
# b  96.0  62.0  86.0   NaN
# c  69.0   NaN  66.0   NaN
# d  54.0  58.0  73.0  88.0
# e   NaN   NaN  54.0   NaN

# %%
df ["col2"] > 50
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# Name: col2, dtype: bool

# %%
df[df ["col2"] > 50]
# Out:
#    col1  col2  col3  col4
# b    96    62    86    36
# d    54    58    73    88

# %%
df.col2[df ["col2"] > 50]
# Out:
# b    62
# d    58
# Name: col2, dtype: int32

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.age>50
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: age, Length: 891, dtype: bool

# %%
titanic[titanic.age>50][titanic["survived"] == 1] #yaşı 50den büyük olanlar arasında hayatta olanlar
# Out:
# C:\Users\iremtokuroglu\AppData\Local\Temp\ipykernel_16820\3159219907.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   titanic[titanic.age>50][titanic["survived"] == 1] #yaşı 50den büyük olanlar arasında hayatta olanlar
#      survived  pclass     sex   age  sibsp  parch      fare embarked   class  \
# 11          1       1  female  58.0      0      0   26.5500        S   First
# 15          1       2  female  55.0      0      0   16.0000        S  Second
# 195         1       1  female  58.0      0      0  146.5208        C   First
# 268         1       1  female  58.0      0      1  153.4625        S   First
# 275         1       1  female  63.0      1      0   77.9583        S   First
# 366         1       1  female  60.0      1      0   75.2500        C   First
# 449         1       1    male  52.0      0      0   30.5000        S   First
# 483         1       3  female  63.0      0      0    9.5875        S   Third
# 496         1       1  female  54.0      1      0   78.2667        C   First
# 513         1       1  female  54.0      1      0   59.4000        C   First
# 570         1       2    male  62.0      0      0   10.5000        S  Second
# 571         1       1  female  53.0      2      0   51.4792        S   First
# 587         1       1    male  60.0      1      1   79.2000        C   First
# 591         1       1  female  52.0      1      0   78.2667        C   First
# 630         1       1    male  80.0      0      0   30.0000        S   First
# 647         1       1    male  56.0      0      0   35.5000        C   First
# 765         1       1  female  51.0      1      0   77.9583        S   First
# 774         1       2  female  54.0      1      3   23.0000        S  Second
# 820         1       1  female  52.0      1      1   93.5000        S   First
# 829         1       1  female  62.0      0      0   80.0000      NaN   First
# 857         1       1    male  51.0      0      0   26.5500        S   First
# 879         1       1  female  56.0      0      1   83.1583        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 11   woman       False    C  Southampton   yes   True
# 15   woman       False  NaN  Southampton   yes   True
# 195  woman       False    B    Cherbourg   yes   True
# 268  woman       False    C  Southampton   yes  False
# 275  woman       False    D  Southampton   yes  False
# 366  woman       False    D    Cherbourg   yes  False
# 449    man        True    C  Southampton   yes   True
# 483  woman       False  NaN  Southampton   yes   True
# 496  woman       False    D    Cherbourg   yes  False
# 513  woman       False  NaN    Cherbourg   yes  False
# 570    man        True  NaN  Southampton   yes   True
# 571  woman       False    C  Southampton   yes  False
# 587    man        True    B    Cherbourg   yes  False
# 591  woman       False    D    Cherbourg   yes  False
# 630    man        True    A  Southampton   yes   True
# 647    man        True    A    Cherbourg   yes   True
# 765  woman       False    D  Southampton   yes  False
# 774  woman       False  NaN  Southampton   yes  False
# 820  woman       False    B  Southampton   yes  False
# 829  woman       False    B          NaN   yes   True
# 857    man        True    E  Southampton   yes   True
# 879  woman       False    C    Cherbourg   yes  False

# %%
titanic[(titanic.age > 50) | (titanic.survived == 1)]
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 6           0       1    male  54.0      0      0  51.8625        S   First
# 8           1       3  female  27.0      0      2  11.1333        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 875         1       3  female  15.0      0      0   7.2250        C   Third
# 879         1       1  female  56.0      0      1  83.1583        C   First
# 880         1       2  female  25.0      0      1  26.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 889         1       1    male  26.0      0      0  30.0000        C   First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 8    woman       False  NaN  Southampton   yes  False
# ..     ...         ...  ...          ...   ...    ...
# 875  child       False  NaN    Cherbourg   yes   True
# 879  woman       False    C    Cherbourg   yes  False
# 880  woman       False  NaN  Southampton   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [384 rows x 15 columns]

# %%
titanic[(titanic.age > 50) & (titanic.survived == 1)].shape #and ve or ifadesi çalışmıyor
# Out:
# (22, 15)

# %%
len(titanic[(titanic.age > 50) & (titanic.survived == 1)])
# Out:
# 22

# %% [markdown]
# ## <font color='blue'> <b>reset_index() & set_index()</b><font color='black'>

# %% [markdown]
# reset_index(), DataFrame indeksini sıfırlar ve bunun yerine default hali kullanır.
#
# set_index(), DataFrame'in belirtilen bir sütununu veya sütunlarını, DataFrame'in yeni bir indeksi olarak ayarlar.

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.set_index("pclass") #pclasıı index olarak ayarla
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN  Southampton    no  False
# 1            False    C    Cherbourg   yes  False
# 3            False  NaN  Southampton   yes   True
# 1            False    C  Southampton   yes  False
# 3             True  NaN  Southampton    no   True
# ...            ...  ...          ...   ...    ...
# 2             True  NaN  Southampton    no   True
# 1            False    B  Southampton   yes   True
# 3            False  NaN  Southampton    no  False
# 1             True    C    Cherbourg   yes   True
# 3             True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic.set_index("pclass", drop=False) #pclasıı hem index olarak ayarla hem de sütun olarak kullanmaya devam et.drop defaultta true olduğu için üsttekki örnekte sütunluktan çıktı.inplace=True yapmadığım için kalıcı değişiklik yapmadı.
# Out:
#         survived  pclass     sex   age  sibsp  parch     fare embarked  \
# pclass
# 3              0       3    male  22.0      1      0   7.2500        S
# 1              1       1  female  38.0      1      0  71.2833        C
# 3              1       3  female  26.0      0      0   7.9250        S
# 1              1       1  female  35.0      1      0  53.1000        S
# 3              0       3    male  35.0      0      0   8.0500        S
# ...          ...     ...     ...   ...    ...    ...      ...      ...
# 2              0       2    male  27.0      0      0  13.0000        S
# 1              1       1  female  19.0      0      0  30.0000        S
# 3              0       3  female   NaN      1      2  23.4500        S
# 1              1       1    male  26.0      0      0  30.0000        C
# 3              0       3    male  32.0      0      0   7.7500        Q
#
#          class    who  adult_male deck  embark_town alive  alone
# pclass
# 3        Third    man        True  NaN  Southampton    no  False
# 1        First  woman       False    C    Cherbourg   yes  False
# 3        Third  woman       False  NaN  Southampton   yes   True
# 1        First  woman       False    C  Southampton   yes  False
# 3        Third    man        True  NaN  Southampton    no   True
# ...        ...    ...         ...  ...          ...   ...    ...
# 2       Second    man        True  NaN  Southampton    no   True
# 1        First  woman       False    B  Southampton   yes   True
# 3        Third  woman       False  NaN  Southampton    no  False
# 1        First    man        True    C    Cherbourg   yes   True
# 3        Third    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.set_index("pclass", drop="False", inplace=True)
titanic
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN  Southampton    no  False
# 1            False    C    Cherbourg   yes  False
# 3            False  NaN  Southampton   yes   True
# 1            False    C  Southampton   yes  False
# 3             True  NaN  Southampton    no   True
# ...            ...  ...          ...   ...    ...
# 2             True  NaN  Southampton    no   True
# 1            False    B  Southampton   yes   True
# 3            False  NaN  Southampton    no  False
# 1             True    C    Cherbourg   yes   True
# 3             True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic.reset_index()
# Out:
#      pclass  survived     sex   age  sibsp  parch     fare embarked   class  \
# 0         3         0    male  22.0      1      0   7.2500        S   Third
# 1         1         1  female  38.0      1      0  71.2833        C   First
# 2         3         1  female  26.0      0      0   7.9250        S   Third
# 3         1         1  female  35.0      1      0  53.1000        S   First
# 4         3         0    male  35.0      0      0   8.0500        S   Third
# ..      ...       ...     ...   ...    ...    ...      ...      ...     ...
# 886       2         0    male  27.0      0      0  13.0000        S  Second
# 887       1         1  female  19.0      0      0  30.0000        S   First
# 888       3         0  female   NaN      1      2  23.4500        S   Third
# 889       1         1    male  26.0      0      0  30.0000        C   First
# 890       3         0    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic
# Out:
#         survived     sex   age  sibsp  parch     fare embarked   class    who  \
# pclass
# 3              0    male  22.0      1      0   7.2500        S   Third    man
# 1              1  female  38.0      1      0  71.2833        C   First  woman
# 3              1  female  26.0      0      0   7.9250        S   Third  woman
# 1              1  female  35.0      1      0  53.1000        S   First  woman
# 3              0    male  35.0      0      0   8.0500        S   Third    man
# ...          ...     ...   ...    ...    ...      ...      ...     ...    ...
# 2              0    male  27.0      0      0  13.0000        S  Second    man
# 1              1  female  19.0      0      0  30.0000        S   First  woman
# 3              0  female   NaN      1      2  23.4500        S   Third  woman
# 1              1    male  26.0      0      0  30.0000        C   First    man
# 3              0    male  32.0      0      0   7.7500        Q   Third    man
#
#         adult_male deck  embark_town alive  alone
# pclass
# 3             True  NaN  Southampton    no  False
# 1            False    C    Cherbourg   yes  False
# 3            False  NaN  Southampton   yes   True
# 1            False    C  Southampton   yes  False
# 3             True  NaN  Southampton    no   True
# ...            ...  ...          ...   ...    ...
# 2             True  NaN  Southampton    no   True
# 1            False    B  Southampton   yes   True
# 3            False  NaN  Southampton    no  False
# 1             True    C    Cherbourg   yes   True
# 3             True  NaN   Queenstown    no   True
#
# [891 rows x 14 columns]

# %%
titanic = sns.load_dataset("titanic")
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic.dropna() # içinde NaN olan bütün satırları siler.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 1           1       1  female  38.0      1      0  71.2833        C  First
# 3           1       1  female  35.0      1      0  53.1000        S  First
# 6           0       1    male  54.0      0      0  51.8625        S  First
# 10          1       3  female   4.0      1      1  16.7000        S  Third
# 11          1       1  female  58.0      0      0  26.5500        S  First
# ..        ...     ...     ...   ...    ...    ...      ...      ...    ...
# 871         1       1  female  47.0      1      1  52.5542        S  First
# 872         0       1    male  33.0      0      0   5.0000        S  First
# 879         1       1  female  56.0      0      1  83.1583        C  First
# 887         1       1  female  19.0      0      0  30.0000        S  First
# 889         1       1    male  26.0      0      0  30.0000        C  First
#
#        who  adult_male deck  embark_town alive  alone
# 1    woman       False    C    Cherbourg   yes  False
# 3    woman       False    C  Southampton   yes  False
# 6      man        True    E  Southampton    no   True
# 10   child       False    G  Southampton   yes  False
# 11   woman       False    C  Southampton   yes   True
# ..     ...         ...  ...          ...   ...    ...
# 871  woman       False    D  Southampton   yes  False
# 872    man        True    B  Southampton    no   True
# 879  woman       False    C    Cherbourg   yes  False
# 887  woman       False    B  Southampton   yes   True
# 889    man        True    C    Cherbourg   yes   True
#
# [182 rows x 15 columns]

# %%
titanic.drop([3,100,150,142,888], inplace=True)

# %%
titanic.reset_index()
# Out:
#      index  survived  pclass     sex   age  sibsp  parch     fare embarked  \
# 0        0         0       3    male  22.0      1      0   7.2500        S
# 1        1         1       1  female  38.0      1      0  71.2833        C
# 2        2         1       3  female  26.0      0      0   7.9250        S
# 3        4         0       3    male  35.0      0      0   8.0500        S
# 4        5         0       3    male   NaN      0      0   8.4583        Q
# ..     ...       ...     ...     ...   ...    ...    ...      ...      ...
# 881    885         0       3  female  39.0      0      5  29.1250        Q
# 882    886         0       2    male  27.0      0      0  13.0000        S
# 883    887         1       1  female  19.0      0      0  30.0000        S
# 884    889         1       1    male  26.0      0      0  30.0000        C
# 885    890         0       3    male  32.0      0      0   7.7500        Q
#
#       class    who  adult_male deck  embark_town alive  alone
# 0     Third    man        True  NaN  Southampton    no  False
# 1     First  woman       False    C    Cherbourg   yes  False
# 2     Third  woman       False  NaN  Southampton   yes   True
# 3     Third    man        True  NaN  Southampton    no   True
# 4     Third    man        True  NaN   Queenstown    no   True
# ..      ...    ...         ...  ...          ...   ...    ...
# 881   Third  woman       False  NaN   Queenstown    no  False
# 882  Second    man        True  NaN  Southampton    no   True
# 883   First  woman       False    B  Southampton   yes   True
# 884   First    man        True    C    Cherbourg   yes   True
# 885   Third    man        True  NaN   Queenstown    no   True
#
# [886 rows x 16 columns]

# %%
titanic.reset_index(drop=True) #drop=True index labelın sütün olarak kalmasını engeller.
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           0       3    male  35.0      0      0   8.0500        S   Third
# 4           0       3    male   NaN      0      0   8.4583        Q   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 881         0       3  female  39.0      0      5  29.1250        Q   Third
# 882         0       2    male  27.0      0      0  13.0000        S  Second
# 883         1       1  female  19.0      0      0  30.0000        S   First
# 884         1       1    male  26.0      0      0  30.0000        C   First
# 885         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3      man        True  NaN  Southampton    no   True
# 4      man        True  NaN   Queenstown    no   True
# ..     ...         ...  ...          ...   ...    ...
# 881  woman       False  NaN   Queenstown    no  False
# 882    man        True  NaN  Southampton    no   True
# 883  woman       False    B  Southampton   yes   True
# 884    man        True    C    Cherbourg   yes   True
# 885    man        True  NaN   Queenstown    no   True
#
# [886 rows x 15 columns]

# %% [markdown]
# # <font color='green'> <b>Some Useful Methods with Titanic Dataset</b><font color='black'>

# %%
titanic = sns.load_dataset("titanic")
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %% [markdown]
# # <font color='green'> <b>Groupby & Aggregation Methods (aggregate() & agg())</b><font color='white'>
#
# groupby(); bir veri setindeki belirli bir sütuna göre gruplama yapmak için kullanılır.
#
# Bu işlev, verileri gruplara ayırmak ve bu gruplar üzerinde çeşitli işlemler yapmak için kullanılır.
#
# Örneğin, bir veri kümesinde müşterilerin isimleri, yaşları ve satın aldıkları ürünler yer alıyor olabilir. groupby() işlevi kullanarak, müşterilerin satın aldıkları ürüne göre gruplandırabilir ve her ürün için ortalama yaşlarını bulabilirsiniz.
#
# [Source01](https://towardsdatascience.com/all-pandas-groupby-you-should-know-for-grouping-data-and-performing-operations-2a8ec1327b5),
# [Source02](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.groupby.html),
# [Source03](https://naomi-fridman.medium.com/pandas-groupby-explained-with-titanic-6a1c47eb8182)
# Pandas'ın aggregation yöntemleri, belirli bir veri kümesi üzerinde işlemler gerçekleştirerek bir sonuç döndürür.
#
# Bu yöntemler, bir veri kümesindeki değerleri toplama, ortalama alma, en büyük veya en küçük değeri bulma gibi farklı işlemleri gerçekleştirir.
#
#
# Pandas'ın aggregation yöntemlerinden bazıları şunlardır:
#
# **sum():** Belirtilen sütunda yer alan tüm değerlerin toplamını döndürür.
#
# **mean():** Belirtilen sütunda yer alan tüm değerlerin ortalamasını döndürür.
#
# **median():** Gruplanmış verilerin medyanını hesaplar.
#
# **mode()** Belirtilen sütunda en çok tekrar eden değerleri döndürür.
#
# **max():** Belirtilen sütunda yer alan en büyük değeri döndürür.
#
# **min():** Belirtilen sütunda yer alan en küçük değeri döndürür.
#
# **count():** Belirtilen sütunda yer alan toplam değer sayısını döndürür.
#
# **std():** Belirtilen sütunda yer alan değerlerin standart sapmasını döndürür.
#
# **var():** Belirtilen sütunda yer alan değerlerin varyansını döndürür.
#
# **describe():** Gruplanmış verilerin istatistiksel özetini hesaplar.
#
# **idxmin():** Belirtilen eksen boyunca minimum değeri içeren ilk indeksi döndürür.
#
# **idxmax():** Belirtilen eksen boyunca maksimum değeri içeren ilk indeksi döndürür.
#
# **corr():** Sütunlar  arasındaki korelasyonu, NA/null değerleri hariç tutarak hesaplar.
#
# Bu yöntemler, bir DataFrame veya Series üzerinde kullanılabilir ve istenilen sütun veya satırlarda işlem yapılabilir.
#
# Pandas'ın aggregation yöntemleri, verileri hızlı ve etkili bir şekilde analiz etmek için çok kullanışlıdır.
#
# [Pandas Official Documentation](https://pandas.pydata.org/docs/reference/frame.html)

# %% [markdown]
# Belirli bir sütuna veya sütunlara göre gruplandırılmış bir veri kümesinde farklı işlevlerin (örneğin, mean, sum, max) uygulanması için kullanılır.
#
# [aggregate](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.aggregate.html),
# [agg](https://pandas.pydata.org/pandas-docs/version/0.23/generated/pandas.core.groupby.DataFrameGroupBy.agg.html),
# [SOURCE01](https://www.shanelynn.ie/summarising-aggregation-and-grouping-data-in-python-pandas/),
# [SOURCE02](https://www.analyticsvidhya.com/blog/2020/03/groupby-pandas-aggregating-data-python/)

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]

# %%
titanic.groupby("sex")["age"].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
titanic.groupby("sex")[["age"]].mean()
# Out:
#               age
# sex
# female  27.915709
# male    30.726645

# %%
titanic.groupby("pclass")["fare"].mean()
# Out:
# pclass
# 1    84.154687
# 2    20.662183
# 3    13.675550
# Name: fare, dtype: float64

# %%
titanic.groupby("sex")["age"].describe()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# sex
# female  261.0  27.915709  14.110146  0.75  18.0  27.0  37.0  63.0
# male    453.0  30.726645  14.678201  0.42  21.0  29.0  39.0  80.0

# %%
titanic.groupby("sex")["age"].min()
# Out:
# sex
# female    0.75
# male      0.42
# Name: age, dtype: float64

# %%
titanic.groupby("sex")["age"].max()
# Out:
# sex
# female    63.0
# male      80.0
# Name: age, dtype: float64

# %%
titanic.groupby("sex")["age"].agg([min,max,np.mean])
# Out:
# C:\Users\iremtokuroglu\AppData\Local\Temp\ipykernel_16820\632107600.py:1: FutureWarning: The provided callable <built-in function min> is currently using SeriesGroupBy.min. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "min" instead.
#   titanic.groupby("sex")["age"].agg([min,max,np.mean])
# C:\Users\iremtokuroglu\AppData\Local\Temp\ipykernel_16820\632107600.py:1: FutureWarning: The provided callable <built-in function max> is currently using SeriesGroupBy.max. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "max" instead.
#   titanic.groupby("sex")["age"].agg([min,max,np.mean])
# C:\Users\iremtokuroglu\AppData\Local\Temp\ipykernel_16820\632107600.py:1: FutureWarning: The provided callable <function mean at 0x0000024990F6E980> is currently using SeriesGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   titanic.groupby("sex")["age"].agg([min,max,np.mean])
#          min   max       mean
# sex
# female  0.75  63.0  27.915709
# male    0.42  80.0  30.726645

# %%
titanic.groupby("sex")["age"].agg(["min","max","mean"])
# Out:
#          min   max       mean
# sex
# female  0.75  63.0  27.915709
# male    0.42  80.0  30.726645

# %%
titanic.groupby("sex")["survived"].count()
# Out:
# sex
# female    314
# male      577
# Name: survived, dtype: int64

# %%
titanic.groupby("sex")[df["survived" == 1]].count() #niye çalışmıyor
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: False
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 titanic.groupby("sex")[df["survived" == 1]] #niye çalışmıyor
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\frame.py:4090, in DataFrame.__getitem__(self, key)
#    4088 if self.columns.nlevels > 1:
#    4089     return self._getitem_multilevel(key)
# -> 4090 indexer = self.columns.get_loc(key)
#    4091 if is_integer(indexer):
#    4092     indexer = [indexer]
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: False

# %%
titanic.groupby(["sex","survived"]).count()
# Out:
#                  pclass  age  sibsp  parch  fare  embarked  class  who  \
# sex    survived
# female 0             81   64     81     81    81        81     81   81
#        1            233  197    233    233   233       231    233  233
# male   0            468  360    468    468   468       468    468  468
#        1            109   93    109    109   109       109    109  109
#
#                  adult_male  deck  embark_town  alive  alone
# sex    survived
# female 0                 81     6           81     81     81
#        1                233    91          231    233    233
# male   0                468    61          468    468    468
#        1                109    45          109    109    109

# %%
titanic.groupby(["sex","survived"]).mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1942, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1941 try:
# -> 1942     res_values = self._grouper.agg_series(ser, alt, preserve_dtype=True)
#    1943 except Exception as err:
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:864, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     862     preserve_dtype = True
# --> 864 result = self._aggregate_series_pure_python(obj, func)
#     866 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:885, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     884 for i, group in enumerate(splitter):
# --> 885     res = func(group)
#     886     res = extract_result(res)
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2454, in GroupBy.mean.<locals>.<lambda>(x)
#    2451 else:
#    2452     result = self._cython_agg_general(
#    2453         "mean",
# -> 2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6540, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6532 @doc(make_doc("mean", ndim=1))
#    6533 def mean(
#    6534     self,
#    (...)
#    6538     **kwargs,
#    6539 ):
# -> 6540     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12417, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   12410 def mean(
#   12411     self,
#   12412     axis: Axis | None = 0,
#    (...)
#   12415     **kwargs,
#   12416 ) -> Series | float:
# > 12417     return self._stat_function(
#   12418         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   12419     )
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\generic.py:12374, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12372 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12374 return self._reduce(
#   12375     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12376 )
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\series.py:6448, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6444     raise TypeError(
#    6445         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6446         "with non-numeric dtypes."
#    6447     )
# -> 6448 return op(delegate, skipna=skipna, **kwds)
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\nanops.py:1701, in _ensure_numeric(x)
#    1699 if isinstance(x, str):
#    1700     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1701     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1702 try:
#
# TypeError: Could not convert string 'SSSSSSSSSCSCSSCSSCSSSSSCSSSQSSSSSCSSSSSSSSSSSSQQSSSSSSCQSSSSSQQSQCSSQSSSSSSCSSSQS' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 titanic.groupby(["sex","survived"]).mean()
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:2452, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2445     return self._numba_agg_general(
#    2446         grouped_mean,
#    2447         executor.float_dtype_mapping,
#    2448         engine_kwargs,
#    2449         min_periods=0,
#    2450     )
#    2451 else:
# -> 2452     result = self._cython_agg_general(
#    2453         "mean",
#    2454         alt=lambda x: Series(x, copy=False).mean(numeric_only=numeric_only),
#    2455         numeric_only=numeric_only,
#    2456     )
#    2457     return result.__finalize__(self.obj, method="groupby")
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1998, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1995     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996     return result
# -> 1998 new_mgr = data.grouped_reduce(array_func)
#    1999 res = self._wrap_agged_manager(new_mgr)
#    2000 if how in ["idxmin", "idxmax"]:
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\managers.py:1469, in BlockManager.grouped_reduce(self, func)
#    1465 if blk.is_object:
#    1466     # split on object-dtype blocks bc some columns may raise
#    1467     #  while others do not.
#    1468     for sb in blk._split():
# -> 1469         applied = sb.apply(func)
#    1470         result_blocks = extend_blocks(applied, result_blocks)
#    1471 else:
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\internals\blocks.py:393, in Block.apply(self, func, **kwargs)
#     387 @final
#     388 def apply(self, func, **kwargs) -> list[Block]:
#     389     """
#     390     apply the function to my values; return a block if we are not
#     391     one
#     392     """
# --> 393     result = func(self.values, **kwargs)
#     395     result = maybe_coerce_values(result)
#     396     return self._split_op_result(result)
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1995, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1992     return result
#    1994 assert alt is not None
# -> 1995 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1996 return result
#
# File c:\Users\iremtokuroglu\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1946, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1944     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1945     # preserve the kind of exception that raised
# -> 1946     raise type(err)(msg) from err
#    1948 if ser.dtype == object:
#    1949     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
titanic.groupby(["sex","survived"])["survived"].count()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 titanic.groupby(["sex","survived"])["survived"].count()
#
# NameError: name 'titanic' is not defined

# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '2.2.1'

# %%
titanic.groupby(["sex", "pclass", "survived"])[["survived"]].count()
# Out:
#                survived
# sex    pclass
# female 1             94
#        2             76
#        3            144
# male   1            122
#        2            108
#        3            347

# %%
titanic.groupby(["sex", "pclass"])[["survived"]].value_counts(normalize=True)*100
# Out:
# sex     pclass  survived
# female  1       1           96.808511
#                 0            3.191489
#         2       1           92.105263
#                 0            7.894737
#         3       0           50.000000
#                 1           50.000000
# male    1       0           63.114754
#                 1           36.885246
#         2       0           84.259259
#                 1           15.740741
#         3       0           86.455331
#                 1           13.544669
# Name: proportion, dtype: float64
